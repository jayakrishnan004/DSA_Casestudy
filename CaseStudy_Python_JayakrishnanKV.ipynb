# %% [markdown]
# <a href="https://colab.research.google.com/github/jayakrishnan004/DSA_Casestudy/blob/main/CaseStudy_Python_JayakrishnanKV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Problem: Employee Performance Analyzer.


employees = [
    {"id":101, "name":"Alice", "department":"Data", "salary":65000, "rating":4.5},
    {"id":102, "name":"Bob", "department":"AI", "salary":72000, "rating":4.8},
    {"id":103, "name":"Charlie", "department":"Web", "salary":58000, "rating":3.9},
    {"id":104, "name":"David", "department":"Data", "salary":61000, "rating":4.2},
    {"id":105, "name":"Eva", "department":"AI", "salary":75000, "rating":4.9},
    {"id":106, "name":"Frank", "department":"Cloud", "salary":68000, "rating":4.1},
    {"id":107, "name":"Grace", "department":"Web", "salary":59000, "rating":3.8},
    {"id":108, "name":"Helen", "department":"Data", "salary":70000, "rating":4.6}
]




#  1.Display the total number of employees.

total = 0
for i in employees:
    total = total + 1
print(f"Total Employees: {total}")

# 2.Display the average, highest, and lowest salary.

salary = []
for i in employees:
  salary.append(i["salary"])
  average = sum(salary)/len(salary)
print(f"Average Salary: {average}")
print(f"Highest Salary: {max(salary)}")
print(f"Lowest Salary: {min(salary)}")

#  3.Display the names of employees whose salary is greater than ₹65,000 and whose performance rating is 4.5 or above.

for i in employees:
  if i["salary"]>65000 and i["rating"]>4.5:
    print(i["name"])
    #  Print(f"Employees with Salary>65000 and Rating>=4.5 {i["name"]}")


#  4.Create a dictionary with Employee ID as the key and Employee Name as the value.

emp = {employee["id"]:employee["name"] for employee in employees}
print(emp)

#  5.Create a list containing all employee names, sort it alphabetically, reverse it, and display the first three names.

emp = []
for i in employees:
  emp.append(i["name"])
# print(emp)
emp.sort()
emp.reverse()
print("First Three Employee Names")
for em in emp[:3]:
  print(em)

# 6.Store all Employee IDs in a tuple and display the maximum and minimum Employee ID.

tup = ()
for i in employees:
  tup = tup + (i["id"],)
print("Employee ID Tuple")
print(tup)
print(f"Maximum Employee ID: {max(tup)}")
print(f"Minimum Employee ID: {min(tup)}")

#  7.Create a set of unique departments and display the department names.

dep = set()
for i in employees:
  dep.add(i["department"])
print("Departments")
print(dep)

#  8.Accept an Employee ID from the user and display the employee details if found; otherwise display "Employee Not Found".

e = int(input("Enter Employee ID: "))

found = False

for i in employees:
    if i["id"] == e:
        print("Employee Details:")
        print(f"ID: {i['id']}")
        print(f"Name: {i['name']}")
        print(f"Department: {i['department']}")
        print(f"Salary: {i['salary']}")
        print(f"Rating: {i['rating']}")

        found = True
        break

if found == False:
    print("Employee Not Found")
# Out:
# Total Employees: 8
# Average Salary: 66000.0
# Highest Salary: 75000
# Lowest Salary: 58000
# Bob
# Eva
# Helen
# {101: 'Alice', 102: 'Bob', 103: 'Charlie', 104: 'David', 105: 'Eva', 106: 'Frank', 107: 'Grace', 108: 'Helen'}
# First Three Employee Names
# Helen
# Grace
# Frank
# Employee ID Tuple
# (101, 102, 103, 104, 105, 106, 107, 108)
# Maximum Employee ID: 108
# Minimum Employee ID: 101
# Departments
# {'AI', 'Cloud', 'Web', 'Data'}
# Enter Employee ID: 120
# Employee Not Found
